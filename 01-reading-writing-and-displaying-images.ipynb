# %% [markdown]
# <a href="https://colab.research.google.com/github/mahdieslaminet/Machine_vision_and_image_processing/blob/main/01-reading-writing-and-displaying-images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">خواندن، ذخیره کردن و نمایش تصویر با OpenCv</div>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# با
# import
# پکیج
# OpenCV
# شروع میکنیم.
# </div>

# %%
import cv2

# %%
import numpy as np

# %% [markdown]
# Let's now load our first image

# %%
# We don't need to do this again, but it's a good habit
import cv2

# Load an image using 'imread' specifying the path to image
img = cv2.imread('./images/input.jpg')

# The first parameter will be title shown on image window
# The second parameter is the image varialbe
cv2.imshow('It is a cow!', img)

# 'waitKey' allows us to input information when a image window is open
# By leaving it blank it just waits for anykey to be pressed before
# continuing. By placing numbers (except 0), we can specify a delay for
# how long you keep the window open (time is in milliseconds here)
cv2.waitKey()

# This closes all open windows
# Failure to place this may cause your program to hang in some computers!
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-3-e2b2efccdad9> in <cell line: 0>()
#       7 # The first parameter will be title shown on image window
#       8 # The second parameter is the image varialbe
# ----> 9 cv2.imshow('It is a cow!', img)
#      10
#      11 # 'waitKey' allows us to input information when a image window is open
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
# ...

# %%
# ماونت کردن گوگل درایو
from google.colab import drive
drive.mount('/content/drive')

# مسیر فایل تصویری در گوگل درایو
image_path = '/content/drive/My Drive/images/input.jpg'  # مسیر را بر اساس محل ذخیره‌سازی فایل تنظیم کنید

# ایمپورت OpenCV
import cv2
from google.colab.patches import cv2_imshow

# خواندن تصویر از مسیر مشخص‌شده
img = cv2.imread(image_path)

# بررسی اینکه تصویر با موفقیت بارگذاری شده است
if img is None:
    print("Error: Image not found! Check the file path.")
else:
    # نمایش تصویر
    cv2_imshow(img)

    # منتظر ماندن برای یک ورودی کلیدی
    cv2.waitKey()

    # بستن همه پنجره‌ها
    cv2.destroyAllWindows()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=800x600>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# همان کد بالا بدون کامنت</div>

# %%
# Same as above without the extraneous comments

import cv2

img = cv2.imread('./images/input.jpg')

cv2.imshow('It is a cow!', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">نحوه ذخیره تصاویر در OpenCV</div>

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print (img.shape)
# Out:
# (600, 800, 3)

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">shape ابعاد تصویر را نشان میدهد.</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# دو بعد نخست به ترتیب نشان دهنده‌ی ارتفاع و عرض تصور می‌باشد.
# عدد 3 نیز نمایانگر وجود سه کانال رنگی است.
# </div>

# %%
# Let's print each dimension of the image

print ('Height of Image:', int(img.shape[0]), 'pixels')
print ('Width of Image: ', int(img.shape[1]), 'pixels')
# Out:
# Height of Image: 600 pixels
# Width of Image:  800 pixels

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">ذخیره سازی تصاویر درOpenCV</div>

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('output.jpg', img)
cv2.imwrite('output.png', img)
# Out:
# True

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# True به معنی این است که عملیات با موفقیت انجام شد.
# </div>

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">نمایش در نوت‌بوک با matplotlib</div>

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در واقع سطر و ستون های ماتریس به ترتیب height و width عکس هستند
# <br/>
# رنگ تصویر وارونه است، چرا که ترتیب کانال ها در opencv برعکس اکثر سایر کتابخانه ها BGR است و نه RGB
# </div>

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">تغییر ترتیب کانالهای رنگی ( BGR-> RGB)</div>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# روش 1 : استفاده از numpy
# </div>

# %%
#method1
plt.imshow(img[:,:,::-1])

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# روش 2 : استفاده از OpenCV
# </div>

# %%
#method2
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %% [markdown]
# ### <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">تغییر و دستکاری پیکسلها</div>

# %%
import cv2

img = cv2.imread('./images/input.jpg')
img[200:300,300:500,:] = 255
plt.imshow(img[...,::-1])

# %%
img[200:300,300:500,:] = (0, 0, 255)
plt.imshow(img[...,::-1])
